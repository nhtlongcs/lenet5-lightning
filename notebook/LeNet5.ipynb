# %%
WORKDIR='/content/workspace'

# %% [markdown]
# ## Clone repo

# %%
# !git clone https://github.com/nhtlongcs/LeNet-5-Lightning workspace
# Out:
# Cloning into 'workspace'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 110 (delta 51), reused 99 (delta 40), pack-reused 0
# Receiving objects: 100% (110/110), 25.96 KiB | 12.98 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
# %cd $WORKDIR
# !git pull
# !git checkout master
# !git reset --hard HEAD
# !git pull
# Out:
# /content/workspace
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 7 (delta 4), reused 7 (delta 4), pack-reused 0
# Unpacking objects: 100% (7/7), done.
# From https://github.com/nhtlongcs/LeNet-5-Lightning
#    7c04362..1ccdb20  master     -> origin/master
# Updating 7c04362..1ccdb20
# Fast-forward
#  configs/dropout/lenet-caltech256.yml | 2 +-
#  configs/dropout/lenet-fashion.yml    | 2 +-
#  configs/dropout/lenet-mnist.yml      | 2 +-
#  3 files changed, 3 insertions(+), 3 deletions(-)
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# HEAD is now at 1ccdb20 change exp name
# Already up to date.

# %%
# %%capture
# %cd $WORKDIR
# !pip install -r requirements.txt

# %%
# !pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/workspace
# ...
#   Running setup.py develop for cv-course
# ...

# %% [markdown]
# ## Training guide

# %%
def BestCheckPointPath(prefix):
    import re 
    import os.path as osp
    
    from glob import glob
    
    p = re.compile(r'\d+\.\d+')
    lenet_savedir = glob(prefix)[0]
    lenet_best_cp_ls = glob(osp.join(lenet_savedir, '*/*/*/*.ckpt'))
    lenet_best_cp_ls = [(s, float(p.findall(s)[-1])) for s in lenet_best_cp_ls]
    lenet_best_cp_ls.sort(key=lambda x: x[1])
    return lenet_best_cp_ls[-1][0]

def MNIST_CP():
    return BestCheckPointPath('/content/workspace/runs/LeNetMNIST*')

def FASHION_CP():
    return BestCheckPointPath('/content/workspace/runs/LeNetFashion*')

def CALTECH_CP():
    return BestCheckPointPath('/content/workspace/runs/LeNetCaltech*')

def MNIST2_CP():
    return BestCheckPointPath('/content/workspace/runs/LeNetDropOutMNIST*')

def FASHION2_CP():
    return BestCheckPointPath('/content/workspace/runs/LeNetDropOutFashion*')

def CALTECH2_CP():
    return BestCheckPointPath('/content/workspace/runs/LeNetDropOutCaltech*')

# %%
WANDB_TOKEN=''

# %%
# !wandb login --relogin $WANDB_TOKEN
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ### TRAIN MNIST

# %%
# %cd $WORKDIR
# !./tools/train.sh configs/base/lenet-mnist.yml
# Out:
# /content/workspace
# Overriding configurating
# Global seed set to 1337
# wandb: Currently logged in as: nhtlong. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path ./runs/LeNetMNIST-2022_06_02-07_55_16/wandb/ wasn't writable, using system temp directory.
# wandb: WARNING Path ./runs/LeNetMNIST-2022_06_02-07_55_16/wandb/ wasn't writable, using system temp directory
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /tmp/wandb/run-20220602_075517-219r0ilz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run LeNetMNIST-2022_06_02-07_55_16
# wandb: ⭐️ View project at https://wandb.ai/nhtlong/vnu-tgmt
# wandb: 🚀 View run at https://wandb.ai/nhtlong/vnu-tgmt/runs/219r0ilz
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...
# 9913344it [00:00, 95092288.01it/s]
# ...

# %%
# !./tools/test.sh configs/base/lenet-mnist.yml {MNIST_CP()}
# Out:
# Overriding configurating
# Global seed set to 1337
# Using 16bit native Automatic Mixed Precision (AMP)
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/utilities.py:94: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   category=PossibleUserWarning,
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# Missing logger folder: /content/workspace/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.7/dist-packages/torchmetrics/utilities/prints.py:36:
# ...
# `full_state_update` that has
#                 not been set for this class (_ResultMetric). The property
# determines if `update` by
#                 default needs access to the full metric state. If this is not
# the case, significant speedups can be
# ...

# %%
# %cd $WORKDIR
# !./tools/train.sh configs/dropout/lenet-mnist.yml
# Out:
# /content/workspace
# Overriding configurating
# Global seed set to 1337
# wandb: Currently logged in as: nhtlong. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path ./runs/LeNetMNIST-2022_06_02-08_04_20/wandb/ wasn't writable, using system temp directory.
# wandb: WARNING Path ./runs/LeNetMNIST-2022_06_02-08_04_20/wandb/ wasn't writable, using system temp directory
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /tmp/wandb/run-20220602_080421-dr2jifss
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run LeNetMNIST-2022_06_02-08_04_20
# wandb: ⭐️ View project at https://wandb.ai/nhtlong/vnu-tgmt
# wandb: 🚀 View run at https://wandb.ai/nhtlong/vnu-tgmt/runs/dr2jifss
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# ...

# %%
# !./tools/test.sh configs/dropout/lenet-mnist.yml {MNIST2_CP()}
# Out:
# Overriding configurating
# Global seed set to 1337
# Using 16bit native Automatic Mixed Precision (AMP)
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/utilities.py:94: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   category=PossibleUserWarning,
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.7/dist-packages/torchmetrics/utilities/prints.py:36:
# ...
# `full_state_update` that has
#                 not been set for this class (_ResultMetric). The property
# determines if `update` by
#                 default needs access to the full metric state. If this is not
# the case, significant speedups can be
#                 achieved and we recommend setting this to `False`.
# ...

# %% [markdown]
# ### TRAIN Fashion mnist

# %%
# %cd $WORKDIR
# !./tools/train.sh configs/base/lenet-fashion.yml
# Out:
# /content/workspace
# Overriding configurating
# Global seed set to 1337
# wandb: Currently logged in as: nhtlong. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path ./runs/LeNetFashion-2022_06_02-08_29_52/wandb/ wasn't writable, using system temp directory.
# wandb: WARNING Path ./runs/LeNetFashion-2022_06_02-08_29_52/wandb/ wasn't writable, using system temp directory
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /tmp/wandb/run-20220602_082953-2hr7yyxi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run LeNetFashion-2022_06_02-08_29_52
# wandb: ⭐️ View project at https://wandb.ai/nhtlong/vnu-tgmt
# wandb: 🚀 View run at https://wandb.ai/nhtlong/vnu-tgmt/runs/2hr7yyxi
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# ...

# %%
# !./tools/test.sh configs/base/lenet-fashion.yml {FASHION_CP()}
# Out:
# Overriding configurating
# Global seed set to 1337
# Using 16bit native Automatic Mixed Precision (AMP)
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/utilities.py:94: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   category=PossibleUserWarning,
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.7/dist-packages/torchmetrics/utilities/prints.py:36:
# ...
# `full_state_update` that has
#                 not been set for this class (_ResultMetric). The property
# determines if `update` by
#                 default needs access to the full metric state. If this is not
# the case, significant speedups can be
#                 achieved and we recommend setting this to `False`.
# ...

# %%
# %cd $WORKDIR
# !./tools/train.sh configs/dropout/lenet-fashion.yml
# Out:
# /content/workspace
# Overriding configurating
# Global seed set to 1337
# wandb: Currently logged in as: nhtlong. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path ./runs/LeNetDropOutFashion-2022_06_02-08_39_57/wandb/ wasn't writable, using system temp directory.
# wandb: WARNING Path ./runs/LeNetDropOutFashion-2022_06_02-08_39_57/wandb/ wasn't writable, using system temp directory
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /tmp/wandb/run-20220602_083958-wf2cspav
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run LeNetDropOutFashion-2022_06_02-08_39_57
# wandb: ⭐️ View project at https://wandb.ai/nhtlong/vnu-tgmt
# wandb: 🚀 View run at https://wandb.ai/nhtlong/vnu-tgmt/runs/wf2cspav
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...

# %%
# !./tools/test.sh configs/dropout/lenet-fashion.yml {FASHION2_CP()}
# Out:
# Overriding configurating
# Global seed set to 1337
# Using 16bit native Automatic Mixed Precision (AMP)
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/utilities.py:94: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   category=PossibleUserWarning,
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.7/dist-packages/torchmetrics/utilities/prints.py:36:
# ...
# `full_state_update` that has
#                 not been set for this class (_ResultMetric). The property
# determines if `update` by
#                 default needs access to the full metric state. If this is not
# the case, significant speedups can be
#                 achieved and we recommend setting this to `False`.
# ...

# %% [markdown]
# ### TRAIN Caltech

# %%
# %cd $WORKDIR
# !./tools/train.sh configs/base/lenet-caltech256.yml
# Out:
# /content/workspace
# Overriding configurating
# Global seed set to 1337
# wandb: Currently logged in as: nhtlong. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path ./runs/LeNetCaltech-2022_06_02-09_01_37/wandb/ wasn't writable, using system temp directory.
# wandb: WARNING Path ./runs/LeNetCaltech-2022_06_02-09_01_37/wandb/ wasn't writable, using system temp directory
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /tmp/wandb/run-20220602_090138-l4i89ny5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run LeNetCaltech-2022_06_02-09_01_37
# wandb: ⭐️ View project at https://wandb.ai/nhtlong/vnu-tgmt
# wandb: 🚀 View run at https://wandb.ai/nhtlong/vnu-tgmt/runs/l4i89ny5
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# ...

# %%
# !./tools/test.sh configs/base/lenet-caltech256.yml {CALTECH_CP()}
# Out:
# Overriding configurating
# Global seed set to 1337
# Using 16bit native Automatic Mixed Precision (AMP)
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/utilities.py:94: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   category=PossibleUserWarning,
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.7/dist-packages/torchmetrics/utilities/prints.py:36:
# ...
# `full_state_update` that has
#                 not been set for this class (_ResultMetric). The property
# determines if `update` by
#                 default needs access to the full metric state. If this is not
# the case, significant speedups can be
#                 achieved and we recommend setting this to `False`.
# ...

# %%
# %cd $WORKDIR
# !./tools/train.sh configs/dropout/lenet-caltech256.yml
# Out:
# /content/workspace
# Overriding configurating
# Global seed set to 1337
# wandb: Currently logged in as: nhtlong. Use `wandb login --relogin` to force relogin
# wandb: WARNING Path ./runs/LeNetDropOutCaltech-2022_06_02-09_30_02/wandb/ wasn't writable, using system temp directory.
# wandb: WARNING Path ./runs/LeNetDropOutCaltech-2022_06_02-09_30_02/wandb/ wasn't writable, using system temp directory
# wandb: Tracking run with wandb version 0.12.17
# wandb: Run data is saved locally in /tmp/wandb/run-20220602_093003-lzbzutb8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run LeNetDropOutCaltech-2022_06_02-09_30_02
# wandb: ⭐️ View project at https://wandb.ai/nhtlong/vnu-tgmt
# wandb: 🚀 View run at https://wandb.ai/nhtlong/vnu-tgmt/runs/lzbzutb8
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# ...

# %%
# !./tools/test.sh configs/dropout/lenet-caltech256.yml {CALTECH2_CP()}
# Out:
# Overriding configurating
# Global seed set to 1337
# Using 16bit native Automatic Mixed Precision (AMP)
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/utilities.py:94: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   category=PossibleUserWarning,
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.7/dist-packages/torchmetrics/utilities/prints.py:36:
# ...
# `full_state_update` that has
#                 not been set for this class (_ResultMetric). The property
# determines if `update` by
#                 default needs access to the full metric state. If this is not
# the case, significant speedups can be
#                 achieved and we recommend setting this to `False`.
# ...
